# %% [markdown]
# # Sprawozdanie - Projekt 2 – implementacja chromosomu rzeczywistego
# Autorzy:
# * Bojarski Bartosz
# * Głowacki Aleksander
# * Kandratsiuk Anastazja
# * Małek Robert
#
# Projekt został wykonany w języku Python w wersji 3.12.0.
#
# ## Wykorzystane biblioteki
# - Tkinter ver. 8.6
# - Numpy ver. 1.26.1
# - Pandas ver. 2.1.1
# - Matplotlib ver. 3.8.0
# - ConfigParser ver. 6.0.0
# - Contourpy ver. 1.1.1
# - Cycler ver. 0.12.1
# - Fonttools ver. 4.43.1
# - Kiwisolver ver. 1.4.5
# - Packaging ver. 23.2
# - Pillow ver. 10.1.0
# - Pyparsing ver. 3.1.1
# - Six ver. 1.16.0
# - Benchmark Functions ver. 1.1.3
# - Scipy ver. 1.11.3

# %%
#Import bibliotek

import benchmark_functions as bf
import opfunu as of
import matplotlib as plt

# %% [markdown]
# ## Analizowana funkcja - Funkcja Rana
#
# Wykres poglądowy:

# %%
func = bf.Rana(n_dimensions=2)
func.show(showPoints=func.minima())
func.show(asHeatMap=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 2
#       1 func = bf.Rana(n_dimensions=2)
# ----> 2 func.show(showPoints=func.minima())
#       3 func.show(asHeatMap=True)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\benchmark_functions\benchmark_functions.py:198, in BenchmarkFunction.show(self, bounds, asHeatMap, resolution, showPoints)
#     196 	Z = np.asarray([[self((X[i][j],Y[i][j])) for j in range(len(X[i]))] for i in range(len(X))])
#     197 fig = plt.figure()
# --> 198 fig.canvas.set_window_title('Benchmark Function: '+self._name)
#     199 fig.suptitle(self._name)
#     200 if asHeatMap:
#
# AttributeError: 'FigureCanvasAgg' object has no attribute 'set_window_title'

# %%
func = of.name_based.r_func.Rana(ndim=2)
plt.pyplot.show(func)

# %% [markdown]
# ## Uruchomienie programu

# %%
! python main.py
# Out:
# Running calculations...
# Range start: -512
# Range end: 512
# Epoch: 100
# Population size: 100
# Precision: 0.1
# Elite strategy: 5
# Variable number: 2
# Cross probability: 20
# Mutation probability: 20
# Inversion probability: 20
# Picked selection_method: best
# Percent to next: 20.0
# Tournaments: 20.0
# Picked cross_method: uniform
# Picked mutation_method: one point
# Picked is min/max "0"
# Is real: "0"
# Exporting...
# C:/Users/Hyperbook/Documents/Magister/OE1/OE1/csv_files/test.csv
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\Hyperbook\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Hyperbook\Documents\Magister\OE1\OE1\app\libs\UI\window.py", line 35, in open
#     Calculations.run_calculations(
#   File "C:\Users\Hyperbook\Documents\Magister\OE1\OE1\app\calculate.py", line 175, in run_calculations
#     Calculations.export_to_csv()
#   File "C:\Users\Hyperbook\Documents\Magister\OE1\OE1\app\calculate.py", line 229, in export_to_csv
#     data = np.reshape(data, (data.shape[0], ))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Hyperbook\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\core\fromnumeric.py", line 285, in reshape
#     return _wrapfunc(a, 'reshape', newshape, order=order)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Hyperbook\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\core\fromnumeric.py", line 59, in _wrapfunc
#     return bound(*args, **kwds)
#            ^^^^^^^^^^^^^^^^^^^^
# ValueError: cannot reshape array of size 2200 into shape (100,)

# %% [markdown]
# ## Zczytanie danych z obliczonego wcześniej programu

# %%
#Tutaj teoretycznie będą 3 subploty, więc wtedy można to opisać w ten sposób, ale ja bym je jakoś rozdzielił, tak jak w tych punktach poniżej.

# %% [markdown]
# ## Wykresy zależności funkcji celu od iteracji

# %% [markdown]
# ## Średnie wartości w kolejnych iteracjach

# %% [markdown]
# ## Odchylenie standardowe w kolejnych iteracjach

# %% [markdown]
# ## Porównanie wyników
#
# * Zakres ∈ <-512;512>
# * Populacja = 100
# * Liczba epok = 200
# * Precyzja = 0.1
# * Liczba bitów = 25
# * Liczba chromosomów używanych w metodach best i tournament = 20
#
# Konfiguarcja #1:
# * Prawdopodobieństwo mutacji: 0
# * Prawdopodobieństwo krzyżowania: 0.4
# * Prawdopodobieństwo inwersji: 0.1
# * Wybrana strategia: Tournament
# * Rodzaj krzyzowania: Two Point
# * Wybrany rodzaj mutacji: n/a
# * Max, czy min: Min
#
# ![Configuration 1](plots/conf1.png)

# %%
# Result found in 0:00:00:03558 seconds
# f(0, 10) = [1.8862700095168572]

# %% [markdown]
# Konfiguarcja - Olek #2:
# * Prawdopodobieństwo mutacji: 50%
# * Prawdopodobieństwo krzyżowania: 50%
# * Prawdopodobieństwo inwersji: 50%
# * Wybrana strategia: Select Best
# * Rodzaj krzyzowania: Two Point
# * Wybrany rodzaj mutacji: Two Point
# * Max, czy min: Min
# ![1cop.PNG](attachment:1cop.PNG)

# %%
# Result found in 0.002016 seconds
# f(0, 10) = [1.8862700095168572]

# %% [markdown]
# Konfiguracja #3:
# * Prawdopodobieństwo mutacji:
# * Prawdopodobieństwo krzyżowania:
# * Prawdopodobieństwo inwersji:
# * Wybrana strategia:
# * Rodzaj krzyzowania:
# * Wybrany rodzaj mutacji:
# * Max, czy min:
#
# ![Configuration 3](plots/conf3.png)

# %% [markdown]
# Konfiguracja #4:
# * Prawdopodobieństwo mutacji: 70%
# * Prawdopodobieństwo krzyżowania: 70%
# * Prawdopodobieństwo inwersji: 70%
# * Wybrana strategia: Roulette
# * Rodzaj krzyzowania: One Point
# * Wybrany rodzaj mutacji: Edge
# * Max, czy min: Max
#
# ![Configuration 4](plots/conf4.png)

# %%
# Result found in 0:00:00:020000 seconds
# f(0, 10) = [1.8862700095168572]

# %% [markdown]
# Tabela z porównaniem wyników:
#
# Będzie wstawiona, gdy będą wyniki.
